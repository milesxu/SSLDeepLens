# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
n = 30
train_loss = np.random.uniform(size=n)
eval_loss = np.random.uniform(size=n)
train_acc = np.random.uniform(size=n)
eval_acc = np.random.uniform(size=n)

# %%
data = pd.DataFrame(
    data={"epoch": np.arange(n), "train loss": train_loss, "evaluation loss": eval_loss, "train accuracy": train_acc, "evaluation accuracy": eval_acc})
data
# Out:
#     epoch  train loss  evaluation loss  train accuracy  evaluation accuracy
# 0       0    0.584924         0.086800        0.904201             0.696093
# 1       1    0.100041         0.447413        0.851271             0.590418
# 2       2    0.532710         0.018913        0.418677             0.343228
# 3       3    0.772805         0.934017        0.891976             0.679789
# 4       4    0.161556         0.984042        0.694937             0.364767
# 5       5    0.667720         0.537514        0.596750             0.566527
# 6       6    0.531956         0.183389        0.052509             0.593962
# 7       7    0.776365         0.966847        0.883367             0.732334
# 8       8    0.627294         0.292103        0.040118             0.908025
# 9       9    0.762048         0.101836        0.616459             0.766101
# 10     10    0.416835         0.900540        0.954186             0.331325
# 11     11    0.638744         0.842041        0.943869             0.361598
# 12     12    0.170633         0.887631        0.149826             0.351279
# 13     13    0.439886         0.498768        0.196794             0.896563
# 14     14    0.964433         0.330515        0.988908             0.927994
# 15     15    0.971149         0.662203        0.184445             0.192317
# 16     16    0.289229         0.414295        0.232605             0.981021
# 17     17    0.426690         0.909615        0.461588             0.366410
# 18     18    0.298258         0.020314        0.833961             0.411560
# 19     19    0.238878         0.129258        0.689630             0.022509
# 20     20    0.646803         0.598907        0.018117             0.307944
# 21     21    0.647693         0.889132        0.611949             0.597953
# 22     22    0.638589         0.387306        0.164764             0.080701
# 23     23    0.714615         0.125671        0.284237             0.253289
# 24     24    0.197114         0.385383        0.057724             0.320883
# 25     25    0.179016         0.370369        0.020230             0.359730
# 26     26    0.715667         0.553050        0.002234             0.188076
# 27     27    0.363989         0.256158        0.010806             0.678435
# 28     28    0.362778         0.927959        0.216910             0.416067
# 29     29    0.300153         0.528803        0.864523             0.850031

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, nrows=1, figsize=(20,10))
data.plot(x='epoch', y='train loss', ax=ax1)
data.plot(x='epoch', y='evaluation loss', color='red', ax=ax1)
data.plot(x='epoch', y='train accuracy', ax=ax2)
data.plot(x='epoch', y='evaluation accuracy', color='red', ax=ax2)
plt.show()
